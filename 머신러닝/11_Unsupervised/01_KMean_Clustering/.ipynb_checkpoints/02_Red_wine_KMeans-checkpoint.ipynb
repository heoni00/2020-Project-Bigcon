# %% [markdown]
# # Red Wine - 데이터 군집 실습
# #### 작성: 고우주 | kubwa 쿱와

# %%
import pandas as pd
import missingno as msno
import seaborn as sns

# %%
# Read the dataset
wine = pd.read_csv('./data/wineQualityReds.csv')

# %%
# First 10 rows
wine.head(10)
# Out:
#    fixed.acidity  volatile.acidity  citric.acid  residual.sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
# 5            7.4              0.66         0.00             1.8      0.075
# 6            7.9              0.60         0.06             1.6      0.069
# 7            7.3              0.65         0.00             1.2      0.065
# 8            7.8              0.58         0.02             2.0      0.073
# 9            7.5              0.50         0.36             6.1      0.071
#
#    free.sulfur.dioxide  total.sulfur.dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
# 5                 13.0                  40.0   0.9978  3.51       0.56
# 6                 15.0                  59.0   0.9964  3.30       0.46
# 7                 15.0                  21.0   0.9946  3.39       0.47
# 8                  9.0                  18.0   0.9968  3.36       0.57
# 9                 17.0                 102.0   0.9978  3.35       0.80
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5
# 5      9.4        5
# 6      9.4        5
# 7     10.0        7
# 8      9.5        7
# 9     10.5        5

# %%
# Data types
wine.dtypes
# Out:
# fixed.acidity           float64
# volatile.acidity        float64
# citric.acid             float64
# residual.sugar          float64
# chlorides               float64
# free.sulfur.dioxide     float64
# total.sulfur.dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# dtype: object

# %%
wine.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed.acidity         1599 non-null   float64
#  1   volatile.acidity      1599 non-null   float64
#  2   citric.acid           1599 non-null   float64
#  3   residual.sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free.sulfur.dioxide   1599 non-null   float64
#  6   total.sulfur.dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
# Size of wine dataset
wine.shape
# Out:
# (1599, 12)

# %%
# Variable names
wine.columns
# Out:
# Index(['fixed.acidity', 'volatile.acidity', 'citric.acid', 'residual.sugar',
#        'chlorides', 'free.sulfur.dioxide', 'total.sulfur.dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
# Missing values
msno.matrix(wine)

# %%
# Statistics of each variable
wine.describe()
# Out:
#        fixed.acidity  volatile.acidity  citric.acid  residual.sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free.sulfur.dioxide  total.sulfur.dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# min       0.012000             1.000000              6.000000     0.990070
# 25%       0.070000             7.000000             22.000000     0.995600
# 50%       0.079000            14.000000             38.000000     0.996750
# 75%       0.090000            21.000000             62.000000     0.997835
# max       0.611000            72.000000            289.000000     1.003690
#
#                 pH    sulphates      alcohol      quality
# count  1599.000000  1599.000000  1599.000000  1599.000000
# mean      3.311113     0.658149    10.422983     5.636023
# std       0.154386     0.169507     1.065668     0.807569
# min       2.740000     0.330000     8.400000     3.000000
# 25%       3.210000     0.550000     9.500000     5.000000
# 50%       3.310000     0.620000    10.200000     6.000000
# 75%       3.400000     0.730000    11.100000     6.000000
# max       4.010000     2.000000    14.900000     8.000000

# %%
sns.pairplot(wine, kind="scatter")

# %%
# Remove the output variable 'quality'
X = wine.drop(labels='quality', axis=1)

# %% [markdown]
# # K-means clustering

# %% [markdown]
# # 1. Number of clusters

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

# %%
k_set = [2, 3, 4, 5, 6, 7, 8, 9, 10]
models = []
sil_scores = []
inertia_scores = []

for k in k_set:
    print('**** KMeans with k = %d ****' % k)
    kmeans = KMeans(n_clusters=k, init='k-means++', n_init=10, max_iter=300, random_state=1234)
    kmeans.fit(X)
    
    inertia_score = kmeans.inertia_
    sil_score = silhouette_score(X, kmeans.predict(X))
    print('inertia score: %.4f' % inertia_score)
    print('silhouette score: %.4f' % sil_score)
    print()
    
    inertia_scores.append(inertia_score)
    sil_scores.append(sil_score)
# Out:
# **** KMeans with k = 2 ****
# inertia score: 691909.8671
# silhouette score: 0.6034
#
# **** KMeans with k = 3 ****
# inertia score: 395309.1835
# silhouette score: 0.5197
#
# **** KMeans with k = 4 ****
# inertia score: 283158.4799
# silhouette score: 0.4897
#
# **** KMeans with k = 5 ****
# inertia score: 221152.9774
# silhouette score: 0.4472
#
# **** KMeans with k = 6 ****
# inertia score: 177331.8863
# silhouette score: 0.4479
#
# **** KMeans with k = 7 ****
# inertia score: 149843.6618
# silhouette score: 0.3940
#
# **** KMeans with k = 8 ****
# inertia score: 132783.3825
# silhouette score: 0.3980
#
# **** KMeans with k = 9 ****
# inertia score: 116510.5144
# silhouette score: 0.3871
#
# **** KMeans with k = 10 ****
# inertia score: 101682.9749
# silhouette score: 0.3842

# %% [markdown]
# # [HW] MinMaxScaler vs. StandardScaler

# %%
from sklearn.preprocessing import MinMaxScaler, StandardScaler

# %%
# scaler = MinMaxScaler(feature_range=(0, 1))
# scaler = MinMaxScaler(feature_range=(-1, 1))
scaler = StandardScaler()

# %%
X_scaled = scaler.fit_transform(X)

# %%
k_set = [2, 3, 4, 5, 6, 7, 8, 9, 10]
models = []
sil_scores = []
inertia_scores = []

for k in k_set:
    print('**** KMeans with k = %d ****' % k)
    kmeans = KMeans(n_clusters=k, init='k-means++', n_init=10, max_iter=300, random_state=1234)
    kmeans.fit(X_scaled)
    
    inertia_score = kmeans.inertia_
    sil_score = silhouette_score(X_scaled, kmeans.predict(X_scaled))
    print('inertia score: %.4f' % inertia_score)
    print('silhouette score: %.4f' % sil_score)
    print()
    
    inertia_scores.append(inertia_score)
    sil_scores.append(sil_score)
# Out:
# **** KMeans with k = 2 ****
# inertia score: 14330.1425
# silhouette score: 0.2139
#
# **** KMeans with k = 3 ****
# inertia score: 12629.9660
# silhouette score: 0.1894
#
# **** KMeans with k = 4 ****
# inertia score: 11294.3828
# silhouette score: 0.2057
#
# **** KMeans with k = 5 ****
# inertia score: 10155.4127
# silhouette score: 0.1904
#
# **** KMeans with k = 6 ****
# inertia score: 9362.0516
# silhouette score: 0.1942
#
# **** KMeans with k = 7 ****
# inertia score: 8645.8212
# silhouette score: 0.1902
#
# **** KMeans with k = 8 ****
# inertia score: 8302.8943
# silhouette score: 0.1488
#
# **** KMeans with k = 9 ****
# inertia score: 7967.9650
# silhouette score: 0.1541
#
# **** KMeans with k = 10 ****
# inertia score: 7701.8723
# silhouette score: 0.1489

# %%
# scaler = MinMaxScaler(feature_range=(0, 1))
# scaler = MinMaxScaler(feature_range=(-1, 1))
scaler = StandardScaler()

# %%
X_scaled = scaler.fit_transform(X)

# %%
k_set = [2, 3, 4, 5, 6, 7, 8, 9]
models = []
sil_scores = []
inertia_scores = []

for k in k_set:
    print('**** KMeans with k = %d ****' % k)
    kmeans = KMeans(n_clusters=k, init='k-means++', n_init=10, max_iter=300, random_state=1234)
    kmeans.fit(X_scaled)
    
    inertia_score = kmeans.inertia_
    sil_score = silhouette_score(X_scaled, kmeans.predict(X_scaled))
    print('inertia score: %.4f' % inertia_score)
    print('silhouette score: %.4f' % sil_score)
    print()
    
    inertia_scores.append(inertia_score)
    sil_scores.append(sil_score)
# Out:
# **** KMeans with k = 2 ****
# inertia score: 14330.1425
# silhouette score: 0.2139
#
# **** KMeans with k = 3 ****
# inertia score: 12629.9660
# silhouette score: 0.1894
#
# **** KMeans with k = 4 ****
# inertia score: 11294.3828
# silhouette score: 0.2057
#
# **** KMeans with k = 5 ****
# inertia score: 10155.4127
# silhouette score: 0.1904
#
# **** KMeans with k = 6 ****
# inertia score: 9362.0516
# silhouette score: 0.1942
#
# **** KMeans with k = 7 ****
# inertia score: 8645.8212
# silhouette score: 0.1902
#
# **** KMeans with k = 8 ****
# inertia score: 8302.8943
# silhouette score: 0.1488
#
# **** KMeans with k = 9 ****
# inertia score: 7967.9650
# silhouette score: 0.1541
